# %%
from src.EDA_Summary.Univariate_Analysis.Statistics.numeric import uni_num_stats
from src.EDA_Summary.Univariate_Analysis.LLm_Summarisation.num_stat_summarization import execute_univariate_num_eda
from src.Utils.columns_classifier import classify_columns

classify_columns()
uni_num_stats()
execute_univariate_num_eda()
# Out:
# [2026-09-21 13:23:34] [INFO] [columns_classifier.py:142] [classify_columns] Reading dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 13:23:34] [INFO] [columns_classifier.py:95] [analyze_eda_columns_with_llm] Sampling DataFrame for column classification...
# [2026-09-21 13:23:35] [INFO] [columns_classifier.py:126] [analyze_eda_columns_with_llm] Triggering LLM completion request with fallback support...
# [2026-09-21 13:23:35] [INFO] [columns_classifier.py:66] [_execute_with_retry] Attempt 1/3 using GroqStrategy...
# [2026-09-21 13:23:37] [INFO] [columns_classifier.py:129] [analyze_eda_columns_with_llm] Successfully received and parsed classification response.
# [2026-09-21 13:23:37] [INFO] [columns_classifier.py:145] [classify_columns] analyze_eda_columns_with_llm completed | Time: 3.11s | Memory: +3.17 MB | Peak: +0 B
# ...

# %%
from src.EDA_Summary.Univariate_Analysis.Statistics.categorical import uni_cat_stats
from src.EDA_Summary.Univariate_Analysis.LLm_Summarisation.cat_stat_summarization import execute_univariate_cat_eda

uni_cat_stats()
execute_univariate_cat_eda()
# Out:
# [2026-09-21 13:28:23] [INFO] [categorical.py:352] [run_from_file] Attempting to load dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 13:28:24] [INFO] [categorical.py:359] [run_from_file] Dataset successfully loaded with shape: (15000, 16)
# [2026-09-21 13:28:24] [INFO] [categorical.py:328] [run_eda] Starting CATEGORICAL-UNI exploratory data analysis...
# [2026-09-21 13:28:24] [INFO] [categorical.py:59] [get_categorical_columns] load_classified_columns completed | Time: 0.00s | Memory: +146.09 KB | Peak: +0 B
# [2026-09-21 13:28:24] [INFO] [categorical.py:71] [get_categorical_columns] Loaded 6 categorical columns from JSON config
# [2026-09-21 13:28:24] [INFO] [categorical.py:333] [run_eda] get_categorical_columns completed | Time: 0.01s | Memory: +6.46 KB | Peak: +0 B
# [2026-09-21 13:28:24] [INFO] [categorical.py:98] [generate_basic_statistics] Computing basic statistics for 6 categorical features...
# ...

# %% [markdown]
# ## BIVARIATE_EDA

# %%
from src.EDA_Summary.Bivariate_Analysis.Statistics.num_num import num_num_stats
from src.EDA_Summary.Bivariate_Analysis.LLm_Summarisation.num_num_stat_summarization import execute_bivariate_num_num_eda

num_num_stats()
execute_bivariate_num_num_eda()
# Out:
# [2026-09-21 20:45:20] [INFO] [num_num.py:209] [run_from_file] Attempting to load dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 20:45:20] [INFO] [num_num.py:216] [run_from_file] Dataset successfully loaded with shape: (15000, 16)
# [2026-09-21 20:45:20] [INFO] [num_num.py:186] [run_eda] Starting NUMERIC-NUMERIC exploratory data analysis...
# [2026-09-21 20:45:20] [INFO] [num_num.py:47] [get_numeric_columns] load_classified_columns completed | Time: 0.00s | Memory: +3.55 KB | Peak: +0 B
# [2026-09-21 20:45:20] [INFO] [num_num.py:187] [run_eda] get_numeric_columns completed | Time: 0.01s | Memory: -130.92 KB | Peak: +0 B
# [2026-09-21 20:45:20] [INFO] [num_num.py:192] [run_eda] Resolved 7 numeric columns for NUM-NUM EDA.
# [2026-09-21 20:45:20] [INFO] [num_num.py:91] [generate_pearson_correlation] Computing Pearson correlations for 7 numeric features...
# ...

# %%
from src.EDA_Summary.Bivariate_Analysis.Statistics.num_cat import num_cat_stats
from src.EDA_Summary.Bivariate_Analysis.LLm_Summarisation.num_cat_stat_summarization import execute_bivariate_num_cat_eda

num_cat_stats()
execute_bivariate_num_cat_eda()
# Out:
# [2026-09-21 20:47:44] [INFO] [num_cat.py:379] [run_from_file] Dataset loaded with shape: (15000, 16)
# [2026-09-21 20:47:44] [INFO] [num_cat.py:346] [run_eda] Starting NUMERIC-CATEGORICAL EDA...
# [2026-09-21 20:47:44] [INFO] [num_cat.py:49] [_get_columns] load_classified_columns completed | Time: 0.00s | Memory: +146.17 KB | Peak: +0 B
# [2026-09-21 20:47:44] [INFO] [num_cat.py:65] [get_numeric_columns] _get_columns completed | Time: 0.01s | Memory: +147.74 KB | Peak: +0 B
# [2026-09-21 20:47:44] [INFO] [num_cat.py:347] [run_eda] get_numeric_columns completed | Time: 0.01s | Memory: +8.07 KB | Peak: +0 B
# [2026-09-21 20:47:44] [INFO] [num_cat.py:49] [_get_columns] load_classified_columns completed | Time: 0.00s | Memory: +3.20 KB | Peak: +0 B
# [2026-09-21 20:47:44] [INFO] [num_cat.py:69] [get_categorical_columns] _get_columns completed | Time: 0.00s | Memory: -140.09 KB | Peak: +0 B
# ...

# %%
from src.EDA_Summary.Bivariate_Analysis.Statistics.cat_cat import cat_cat_stats
from src.EDA_Summary.Bivariate_Analysis.LLm_Summarisation.cat_cat_stat_summarization import execute_bivariate_cat_cat_eda

cat_cat_stats()
execute_bivariate_cat_cat_eda()
# Out:
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:275] [run_from_file] Loading dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:281] [run_from_file] Dataset loaded with shape: (15000, 16)
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:255] [run_eda] _validate_dataframe completed | Time: 0.00s | Memory: +456 B | Peak: +0 B
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:60] [get_categorical_columns] load_classified_columns completed | Time: 0.00s | Memory: +145.90 KB | Peak: +0 B
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:65] [get_categorical_columns] Resolved 6 categorical columns from classification.
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:257] [run_eda] get_categorical_columns completed | Time: 0.01s | Memory: +147.96 KB | Peak: +0 B
# [2026-09-21 20:50:40] [INFO] [cat_cat.py:261] [run_eda] Starting CAT-CAT EDA with columns: ['Gender', 'City', 'Product_Category', 'Product', 'Payment_Method', 'Returned']
# ...

# %%
from src.EDA_Summary.Bivariate_Analysis.Statistics.num_dt import num_datetime_stats
from src.EDA_Summary.Bivariate_Analysis.LLm_Summarisation.num_dt_stat_summarization import execute_bivariate_num_datetime_eda

num_datetime_stats()
execute_bivariate_num_datetime_eda()
# Out:
# [2026-09-21 21:01:40] [INFO] [num_dt.py:594] [run_from_file] Attempting to load dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 21:01:40] [INFO] [num_dt.py:601] [run_from_file] Dataset successfully loaded. Shape: (15000, 16)
# [2026-09-21 21:01:40] [INFO] [num_dt.py:557] [run_eda] _validate_dataframe completed | Time: 0.00s | Memory: +1.29 KB | Peak: +0 B
# [2026-09-21 21:01:40] [INFO] [num_dt.py:81] [get_numeric_columns] load_classified_columns completed | Time: 0.00s | Memory: +3.87 KB | Peak: +0 B
# [2026-09-21 21:01:40] [INFO] [num_dt.py:90] [get_numeric_columns] Resolved 7 numeric columns from classification.
# [2026-09-21 21:01:40] [INFO] [num_dt.py:558] [run_eda] get_numeric_columns completed | Time: 0.01s | Memory: -86.49 KB | Peak: +0 B
# [2026-09-21 21:01:40] [INFO] [num_dt.py:109] [get_datetime_columns] load_classified_columns completed | Time: 0.00s | Memory: +3.25 KB | Peak: +0 B
# ...

# %%
from src.EDA_Summary.Bivariate_Analysis.Statistics.cat_dt import cat_datetime_stats
from src.EDA_Summary.Bivariate_Analysis.LLm_Summarisation.cat_dt_stat_summarization import execute_bivariate_cat_datetime_eda

cat_datetime_stats()
execute_bivariate_cat_datetime_eda()
# Out:
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:469] [run_from_file] Attempting to load dataset from: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:474] [run_from_file] Dataset successfully loaded. Shape: (15000, 16)
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:435] [run_eda] _validate_dataframe completed | Time: 0.00s | Memory: +1.29 KB | Peak: +0 B
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:68] [get_categorical_columns] load_classified_columns completed | Time: 0.00s | Memory: +146.08 KB | Peak: +0 B
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:75] [get_categorical_columns] Resolved 6 categorical columns from classification.
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:436] [run_eda] get_categorical_columns completed | Time: 0.01s | Memory: +39.13 KB | Peak: +0 B
# [2026-09-21 21:07:18] [INFO] [cat_dt.py:86] [get_datetime_columns] load_classified_columns completed | Time: 0.00s | Memory: +3.25 KB | Peak: +0 B
# ...

# %%
from src.EDA_Summary.Multivariate_Analysis.Statistics.multivariate import multivariate_stats
from src.EDA_Summary.Multivariate_Analysis.LLm_Summarisation.multivariate_stat_summarization import execute_multivariate_eda

multivariate_stats(target="Returned")
execute_multivariate_eda()
# Out:
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1187] [run_from_file] Loading dataset: F:\Conversational_Analytics_Agent\src\Data\cleaned_ecommerce_dataset.csv
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1192] [run_from_file] Dataset loaded successfully: 15000 rows x 16 columns.
# [2026-09-21 21:51:02] [INFO] [multivariate.py:149] [_initialize_features] Initialized multivariate features: 5 numeric, 7 categorical.
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1127] [run_eda] Starting Multivariate EDA.
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1131] [run_eda] generate_vif completed | Time: 0.08s | Memory: +331.54 KB | Peak: +0 B
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1136] [run_eda] generate_pca completed | Time: 0.02s | Memory: +56.48 KB | Peak: +0 B
# [2026-09-21 21:51:02] [INFO] [multivariate.py:1142] [run_eda] generate_decision_tree completed | Time: 0.10s | Memory: +441.70 KB | Peak: +5.98 MB
# ...

# %%
from src.Utils.report_aggregation import eda_text_report_generation

eda_text_report_generation()
# Out:
# [CREATED] F:\Conversational_Analytics_Agent\src\Data\EDA_Report\univariate.txt
# [CREATED] F:\Conversational_Analytics_Agent\src\Data\EDA_Report\bivariate.txt
# [CREATED] F:\Conversational_Analytics_Agent\src\Data\EDA_Report\multivariate.txt
#
# EDA report generation completed.

# %%
from src.EDA_RAG.build_main import build_rag
build_rag()
# Out:
# [2026-09-22 23:55:36] [INFO] [document_parser.py:108] [__init__] EDA document parser initialized.
# [2026-09-22 23:55:36] [INFO] [chunker.py:97] [__init__] Initialized EDA semantic chunker: chunk_size=1200, overlap=150, min_size=100
# [2026-09-22 23:55:36] [INFO] [embedder.py:88] [__init__] Embedding service initialized: model=sentence-transformers/all-mpnet-base-v2 | provider=hf-inference | batch_size=32 | normalize=True
# [2026-09-22 23:55:36] [INFO] [vector_store.py:94] [__init__] FAISS vector store initialized: directory=F:\Conversational_Analytics_Agent\src\EDA_RAG\vector_db | model=sentence-transformers/all-mpnet-base-v2
# [2026-09-22 23:55:36] [INFO] [build_vector_db.py:78] [__init__] EDA vector DB builder initialized: dataset_id=DS001
# [2026-09-22 23:55:36] [INFO] [build_vector_db.py:93] [build] Starting EDA vector database construction.
# ...
